# %% [markdown]
# >## **Fundamentos de programación para analítica de datos.**
# >>**Diplomado en métodos estadísticos**
#
# >>**Facultad de Ingeniería y Ciencias Básicas.**
#
# >>**Universidad Central  2023**
#
#
# > >*Profesor: Jorge Victorino*
#
# >**Temas:**
#
# >> Gráficas en python
# >>* Gráficas de dataframes con seaborn
# >>* Uso de otras librerias para graficar
#
# >---

# %% [markdown]
# # Introducción a Seaborn
#
# Seaborn es una libreria de python para la visualiazación de datos basada en matplotlib. Esta librería esta hecha para construir gráficos estadísticos y tiene la ventaja de estar estrechamente integrada a la librería de pandas.
#
# Como siempre, antes de comenzar a producir cualquier gráfico, es necesario tener un amplio entendimiento de la estructura de los datos, así como también, tener el conjunto de datos preprocesado y listo para trabajar. Dentro de las funciones que ofrece Seaborn se destacan las siguientes:
#
# - Esta orientada al trabajo con dataframes de pandas, lo que permite examminar relaciones entre múltiples variables
# - Tiene un gran soporte para el manejo de variables categóricas y para pintar observaciones y estadísticas agregadas
# - Opciones para visualizar distribuciones univaridas y bivariadas
# - Estimación automática como por ejemplo el trazado de modelos de regresión lineal
# - Vistas sobre la estructura general de conjuntos de datos
# - Abstracciones de alto nivel para estructurar cuadrículas de múltiples gráficos
# - Control del estilo con varios temas incorporados
# - Herramientas para elegir paletas de colores
#
# La pregunta fundamental es: __¿Cómo se pueden visualizar datos de alta dimensionalidad de manera apropiada?__

# %% [markdown]
# ##Tips para creación de gráficos efectivos
#
# - Al momento de crear un conjunto de gráficos que presentan algún fenómeno o situación particular, siempre se debe pensar en contar una __historia__.
# - Tenga en cuenta el contexto y la audiencia que va a recibir esta información
# - Seleccionar el gráfico ideal, el que sea más efectivo en cada ocasión
# - El desorden es el enemigo, muchas veces menos es más
# - Enfocar la atención de la audiencia
# - A la hora de cosntruir el gráfico piense como un diseñador para comunicar con datos
#
# Tenga en cuenta que se puede aprender mucho a partir de una completa exploración de visualizaciones efectivas.
#
# Recomendación desde Microsoft-Analytics Storytelling for Impact:
# ![texto alternativo](https://filestore.community.support.microsoft.com/api/images/663d86ea-24b4-4fb5-95d6-e9353d488b27?upload=true)

# %% [markdown]
# ## Alistar la información
#
# Antes de comenzar a graficar es necesario preparar la información. Como siempre es necesario tener un claro entendimiento de los datos que se van a trabajar.
#
# 1. Alistar los datos: Se van a cargar los datos de: examen2, Iris y Breast cancer.
#
#
# ```python
# # 1. base de datos de examen
# import numpy as np
# import pandas as pd
# import seaborn as sns
#
# # Cargar los datos de examen
# dfe = pd.read_excel('examen.xlsx')
# print('Datos externos: Examen:', dfe.shape)
# print('Columnas de Examen:', dfe.columns)
#
# # Cargar los datos iris desde seaborn
# dfi = sns.load_dataset('iris')
# print('Dataset SeaBorn Iris:', dfi.shape)
# print('Columnas de Iris:', dfi.columns)
#
# # nombres de los dataset de seaborn
# print(sns.get_dataset_names())
#
# ```
# Los dataframes de plotly se pueden cargar haciendo:
#
#
# ```python
# import plotly.express as px
# df = px.data.{dataframe}
# ```
#
# ver [Tutorial Seaborn](https://seaborn.pydata.org/tutorial.html)

# %%
# Celda de código para probar
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
 
dfe = pd.read_excel('examen.xlsx')
print('Datos externos: Examen:', dfe.shape)
print('Columnas de Examen:', dfe.columns)
dfi = sns.load_dataset('iris')
print('Dataset SeaBorn Iris:', dfi.shape)
print('Columnas de Iris:', dfi.columns)
# nombres de los dataset de seaborn
print('-'*40)
lst = sns.get_dataset_names()
print('Datasets Seaborn:', lst)
# Out:
# Datos externos: Examen: (619, 33)
# Columnas de Examen: Index(['IDE', 'programa', 'IDG', 'corte1', 'corte2', 'prom', 'fallas',
#        'fallaP', 'curso', 'creditos', 'IDP', 'nestud', 'periodo', 'año',
#        'jornada', 'profesor', 'dedicacion', 'nsala', 'sala', 'horaExamen',
#        'inicio', 'final', 'nota', 'p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7',
#        'p8', 'p9', 'p10'],
#       dtype='object')
# Dataset SeaBorn Iris: (150, 5)
# Columnas de Iris: Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
# ----------------------------------------
# Datasets Seaborn: ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# #### Alistar datos breast_cancer
#
# Existen otras fuentes de datos de ejemplo como el mismo pandas y sklearn entre otros. Ahora se construye el dataframe a parit de fuentes que tienen datos numéricos diseñados para tareas de clasificación como es: Breast Cancer:
#
# ```python
# # Alistar datos Breast cancer
# from sklearn import datasets
# cancer = datasets.load_breast_cancer()
# dfc = pd.DataFrame(cancer.data, columns=cancer.feature_names)
# dfc['diag'] = cancer.target
# print('Datos Breast cancer:', dfc.shape)
# print('Columnas Breast Cancer:', dfc.columns)
# dfc
# ```

# %%
# Celda de código para probar
from sklearn import datasets
cancer = datasets.load_breast_cancer()
dfc = pd.DataFrame(cancer.data, columns=cancer.feature_names)
dfc['diag'] = cancer.target
print('Datos Breast cancer:', dfc.shape)
print('Columnas Breast Cancer:', dfc.columns)
print('---------------------------')
dfc
# Out:
# Datos Breast cancer: (569, 31)
# Columnas Breast Cancer: Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'diag'],
#       dtype='object')
# ---------------------------
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# ...

# %% [markdown]
# ## Tablas de frecuencias y gráficas para variables cualitativas
# La estadística descriptiva se encarga de organizar datos con el fin de mostrar la distribución general de éstos y el lugar en donde tienden a concentrarse, además de señalar valores de datos poco usuales o extremos. El primer procedimiento que se emplea para organizar y resumir un conjunto de datos es una tabla de frecuencias.
#
# <img src="https://antoninoapp.shinyapps.io/semana2/_w_d6dafdb0/www/ana.png"  width="150" height="130">
#
# Si hablamos de frecuencia estadística, podemos definirlo como el número de veces que se repite un dato en una muestra estadística.
#
# Para definir correctamente las frecuencias necesitamos diferenciar entre dos tipos o dos maneras de representarlas:
#
# **Frecuencia Absoluta:** es la definición que entenderíamos habitualmente como frecuencia estadística. Básicamente es el conteo de operaciones que se repiten en una muestra o experimento.

# %%
f_ab=dfe['programa'].value_counts()
f_ab
# Out:
# Ingeniería Ambiental      231
# Ingeniería De Sistemas    144
# Ingeniería Electrónica    110
# Ingeniería Industrial      78
# Ingeniería Mecánica        56
# Name: programa, dtype: int64

# %% [markdown]
# **Frecuencia Relativa:** se trata simplemente del cociente entre la frecuencia absoluta (calculada según las indicaciones del punto anterior) y el tamaño de la muestra o el número de veces que se haya realizado un experimento.

# %%
f_re=f_ab/f_ab.sum()
f_re*100
# Out:
# Ingeniería Ambiental      37.318255
# Ingeniería De Sistemas    23.263328
# Ingeniería Electrónica    17.770598
# Ingeniería Industrial     12.600969
# Ingeniería Mecánica        9.046850
# Name: programa, dtype: float64

# %%
print('Frecuencia absoluta acumulada:','\n',f_ab.cumsum())
print('\n\n','Frecuencia relativa acumulada:','\n',f_re.cumsum())
# Out:
# Frecuencia absoluta acumulada:
#  Ingeniería Ambiental      231
# Ingeniería De Sistemas    375
# Ingeniería Electrónica    485
# Ingeniería Industrial     563
# Ingeniería Mecánica       619
# Name: programa, dtype: int64
#
#
#  Frecuencia relativa acumulada:
#  Ingeniería Ambiental      0.373183
# Ingeniería De Sistemas    0.605816
# Ingeniería Electrónica    0.783522
# Ingeniería Industrial     0.909532
# Ingeniería Mecánica       1.000000
# Name: programa, dtype: float64

# %% [markdown]
# ### Diagrama de barras
# En ella, las clases o categorías se representan en el eje horizontal y la frecuencia de clase en el eje vertical. Las frecuencias de clase son proporcionales a las alturas de las barras.

# %%
sns.barplot(x=f_ab.index, y=f_ab.values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Diagrama de torta
# Gráfica que muestra la parte o porcentaje que representa cada clase del total, de números de frecuencia.

# %%
plt.pie(f_ab,labels=f_ab.index, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ## Gráficas para variables cuantitativas
# <img src="https://antoninoapp.shinyapps.io/semana2/_w_7de46598/www/trend.png"  width="150" height="130">
#
# ### Histogramas
#
#
# Un histograma de frecuencia relativa es semejante a una gráfica de barras, pero se usa para graficar cantidades en lugar de datos cualitativos.Primero, dividimos el intervalo de las mediciones más pequeñas a las más grandes en subintervalos o clases de igual longitud.Si se ponen en columna los puntos de cada subintervalo y se traza una barra sobre cada una de las columnas se habrá creado un histograma de frecuencia o un histograma de frecuencia relativa, dependiendo de la escala del eje vertical.

# %%
sns.histplot(dfe.prom, bins=10)
plt.show()

# %% [markdown]
# ### Gráfica de líneas
# Cuando una variable cuantitativa se registra en el tiempo a intervalos igualmente espaciados (por ejemplo: diario, semanal, mensual, trimestral o anual) el conjunto de datos forma una serie de tiempo.
#
# Para esto usaremos el precio de la acción de apple desde el 17 de febrero del 2015 hasta el 16 de febrero de 2017.

# %%
df_apple =pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')
df_apple.columns
ax=sns.relplot(x='Date', y='AAPL.Close', data=df_apple, kind='line')
ax.set_xticklabels(rotation=30)
plt.show()

# %%
df_apple['date2'] = pd.to_datetime(df_apple['Date'], format = '%Y-%m-%d')
ax=sns.relplot(x='date2', y='AAPL.Close', data=df_apple, kind='line')
ax.set_xticklabels(rotation=30)
plt.show()

# %% [markdown]
# ## Diagrama de caja
#
# Se trata de una representación gráfica sencilla que no necesita un número elevado de valores para su construcción. Sirve para visualizar tanto la dispersión como la forma de una variable. Asimismo, es especialmente útil para comparar diferentes distribuciones de manera simultánea.
#
# Como dice su nombre, consta de una caja, donde la misma representa el cincuenta por ciento central de la distribución (va de
# Q1
#  o primer cuartil a Q3
#  o tercer cuartil), y la línea situada en el interior de la caja es la mediana.
#
# En este gráfico, Q1
#  recibe el nombre de bisagra inferior y Q3
#  bisagra superior. Los extremos inferiores y superiores de los segmentos (también llamados bigotes) delimitan lo que se denomina valores normales y coinciden, respectivamente, con el mínimo y el máximo de los valores una vez excluidos los candidatos a valores anómalos. Los candidatos a valores anómalos se etiquetan como atípicos y coinciden con aquellas observaciones que se encuentran fuera del intervalo (LI,LS) , donde:
#
#  $LI=Q_1−1.5\times R_I,LS=Q_3+1.5\times R_I$
#
#  con $R_i$ llamado el rango intercuartilico definido como $R_I$=$Q_3−Q_1$
# . tomado de [Estadística Básica Edulcorada](https://bookdown.org/aquintela/EBE/medidas-caracteristicas-de-una-variable.html#diagrama-de-caja-box-plot)
#
#
# <img src="https://bookdown.org/aquintela/EBE/Figure/boxplotG.png"  width="8500" height="400">

# %% [markdown]
# ## Gráficas de dispersión
#
# Las gráficas de dispersión se recomiendan para evidenciar relaciones entre variables y para mostrar la distribución de variables que generalmente son numéricas. En general, este es un buen primer paso para observar relaciones y distribución de los datos.
#
# Seaborn dispone de la función __relplot__, la cual presenta variadas e interesantes parametrizaciones.
#
# ### Ejemplo 1
# > Iniciamos cruzando dos variables numéricas usando $x, y$, como ejemplo tomamos el dataframe Iris:
#
#
# ```python
# # importar la libreria de Seaborn
# sns.relplot(x="petal.length", y="sepal.length", data=dfi)
# ```

# %%
# Celda de código para probar
sns.relplot(x="petal_length", y="sepal_length", data=dfi)

# %% [markdown]
# ### Visualizar la clase
#
#
# Para tareas de clasificación resulta útil relacionar las variables con la clase. Para esto se agrega el parámetro __hue__=_'species' a la gráfica de dispersión, ahora se visualiza y se compara con el grafico anterior:
#
#
#
# ```python
# sns.relplot(x="petal_length", y="sepal_length", hue='species', data=dfi)
# ```

# %%
# Probar en esta celda
sns.relplot(x="petal_length", y="sepal_length", hue='species', data=dfi)

# %% [markdown]
# ### Ejercicio
# Probemos ahora otras relaciones, como por ejemplo:
# - 'sepal.length' vs 'sepal.width'
# - 'petal.length' vs 'petal.width'
# - 'sepal.width' vs 'petal.width'

# %%
# Pruebe el ejercicio en esta celda de código

# %% [markdown]
# Para observar todas las relaciones entre las variables continuas se puede usar una función que de Seborn que ejecuta automáticamente el análisis completo:
#
# ```python
# # Función pairplot
# sns.pairplot(data=dfi, hue='species')
# ```

# %%
# Probar en esta celda de código
sns.pairplot(data=dfi, hue='species')

# %% [markdown]
# También es posibile limitar el uso de las variables que se quieren analizar, esto es útil cuando son muchas variables.
#
# ```python
# # Función pairplot
# sns.pairplot(data=dfi, hue='variety',vars=['sepal.length', 'petal.length'])
# ```

# %%
# Probar en esta celda de código
sns.pairplot(data=dfi, hue='species', vars=['sepal_length', 'petal_length'])

# %% [markdown]
# ### Ejercicio 2
#
# 1. Ahora utilice el dataframe de Breast Cancer (dfc) para analizar la relación entre 5 variables, en las que usted piense que hay relación. (recomendación no intente ejecutar con todas las variables por que se va a tardar mucho el procesamiento)
#
# 2. Analice que variables del dtaframe examen2 se pueden visualizar de esta forma?

# %%
# Pruebe el ejercicio en esta celda de código

# %% [markdown]
# ### Otras opciones de visualización de gráficas dispersas
#
# Varias dimensiones se pueden visualizar en una gráfica de dispersión
# - $x$ variable numérica (puede tener múltiples valores)
# - $y$ variable numérica
# - $hue$ variable categórica (agrupa)
# - $size$ diferentes tamaños de la burbuja, variable numérica
# - $style$ pone marcas diferentes, variable categórica (agrupa)
# - $col$ organiza filtros por columna, variable categórica (filtra)
# - $row$ organiza filtros por fila, variable categórica (filtra)
#
# #### Ejemplo
#
#
#
#
#
# ```python
# # Mostrar varias dimensiones con el dataframe de Breast cancer.
# sns.relplot(data=dfc, x='mean perimeter', y='mean area', size='mean radius', sizes=(50, 300), hue='diag')
# # Mostrar varias dimensiones con el dataframe de examen2.
# sns.relplot(data=dfe, x='nota', y='prom', size='fallas', sizes=(50, 300), hue='jornada', row='dedicacion')
#
# ```

# %%
# Pruebe el ejemplo en esta celda de código

# %% [markdown]
# ## Gráficos de líneas múltiple
#
# Generalmente cuando se tienen una o muchas variable numéricas que dependen de una variable independiente y ordenada (como por ejemplo el tiempo), lo ideal es realizar gráficos de líneas. En estos gráficos se pueden representar y comparar fácilmente varias series de datos, así como también mostrar comportamientos asociados a la variable independiente.
#
# Cuando se tienen múltiples valores de la serie por cada valor de la varaiable independiente, se  gráfica de manera automática el intervalo de confianza del 95% calculado usando el método de bootstrapping.
#
#
#
# ```python
# # intervalo de confianza desabilidtado
# sns.relplot(x="nota", y="prom", hue="jornada", ci=False, kind='line',data=dfe)
# # intervalo de confianza habilitado
# sns.relplot(x="nota", y="prom", hue="jornada", kind='line',data=dfe)
# ```

# %%
# Pruebe el ejemplo en esta celda de código

# %% [markdown]
# #### opciones de gráfico
#
# Al igual que los gráficos de dispersión la función permite usar múltiples parámetros para mejorar la visualización e incluir más dimensiones en el anĺaisis.
#
# #### Ejemplo
#
# Agregue los siguiente a la gráfica:
# - style="jornada"
# - row="programa"
# - markers=True
#
# Observe lo que pasa y haga un análisis del resultado.

# %%
sns.relplot(x="nota", y="prom", hue="jornada", style="jornada", col='programa', markers=True, kind='line',data=dfe, height=3)

# %% [markdown]
# ### Ejercicio
#
# Analize y describa las siguientes gráficas.

# %%
sns.relplot(x="nota", y="prom", hue="jornada", col="profesor", size='nestud', height=3, col_wrap=5, kind='line',data=dfe)

# %%
sns.catplot(x="nota", y="profesor", col="programa", kind="box", data=dfe)

# %%
import seaborn as sns

dfd = dfe[dfe['IDP']<=210]
print(dfd.shape)
sns.set_style('whitegrid')
sns.catplot(y="nota", x="profesor", kind="box",    data=dfd, height=4, aspect=4, palette='Set2')
sns.catplot(y='nota', x='profesor', kind='swarm',  data=dfd, height=4, aspect=4, hue='jornada')
sns.catplot(y="nota", x="profesor", kind="violin", data=dfd, height=4, aspect=4, palette='Set2')
# Out:
# (279, 33)

# %%
sns.set(rc={'figure.figsize':(18.0, 5.0)})
sns.set_context("poster")
sns.set_style('whitegrid')
ax = sns.boxplot(  y="nota", x="profesor", data=dfd)
ax = sns.swarmplot(y='nota', x='profesor', data=dfd, color=".2")

# %%
sns.set(rc={'figure.figsize':(18.0, 5.0)})
sns.set_style('whitegrid')
sns.set_context("talk")
ax = sns.violinplot(  y="nota", x="profesor", data=dfd)
ax = sns.swarmplot(y='nota', x='profesor', data=dfd, color="White")

# %%
sns.set(rc={'figure.figsize':(18.0, 5.0)})
sns.set_context("talk")
ax = sns.violinplot(  y="nota", x="profesor", data=dfd)
ax = sns.boxplot(  y="nota", x="profesor", data=dfd, color='White')

# %%
sns.set_context("paper")
ax = sns.violinplot(y="nota", x="profesor", data=dfe)

# %%
ax = sns.catplot(y="nota", x="profesor", kind='boxen',data=dfe, aspect=4)
ax = sns.catplot(y="nota", x="profesor", kind='box',  data=dfe, aspect=4)

# %%
ax = sns.catplot(y="nota", x="profesor", kind='bar',data=dfe, aspect=4)
ax = sns.catplot(y="nota", x="programa", hue='jornada', kind='point',data=dfe, aspect=2)
ax = sns.catplot(x="nota", kind='count',data=dfe, col='programa')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
ax = sns.catplot(x="nota", kind='count',data=dfe, col='profesor', col_wrap=5, height=4)

# %%
sns.set_style('whitegrid')

ax = sns.catplot(y="nota", x="programa", hue='jornada', kind='violin',data=dfe, split=True, aspect=3, palette='Set2')
